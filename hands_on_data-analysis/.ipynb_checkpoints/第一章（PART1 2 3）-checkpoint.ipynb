# %%
import numpy as np
import pandas as pd

# %%
# 相对路径
df = pd.read_csv('train.csv')

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
#绝对路径
df = pd.read_table('/data/hands_on_data-analysis/train.csv')

# %%
df.head(5)
# Out:
#   PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 0  1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/...
# 1  2,1,1,"Cumings, Mrs. John Bradley (Florence Br...
# 2  3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,S...
# 3  4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May ...
# 4  5,0,3,"Allen, Mr. William Henry",male,35,0,0,3...

# %% [markdown]
# ## read_table和read_csv导入的格式不同

# %%
#逐块读取
chunker = pd.read_csv('train.csv',chunksize=1000)

# %%
df = pd.read_csv('train.csv',names=['乘客ID','是否幸存','仓位等级','姓名','性别','年龄','兄弟姐妹个数','父母子女个数','床票信息','票价','客舱','登陆港口'],index_col='乘客ID',header=0)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# # 查看数据的基本信息

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# 是否幸存      891 non-null int64
# 仓位等级      891 non-null int64
# 姓名        891 non-null object
# 性别        891 non-null object
# 年龄        714 non-null float64
# 兄弟姐妹个数    891 non-null int64
# 父母子女个数    891 non-null int64
# 床票信息      891 non-null object
# 票价        891 non-null float64
# 客舱        204 non-null object
# 登陆港口      889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
# df.head(10)
df.tail(15)
# Out:
#       是否幸存  仓位等级                                             姓名      性别    年龄  \
# 乘客ID
# 877      0     3                  Gustafsson, Mr. Alfred Ossian    male  20.0
# 878      0     3                           Petroff, Mr. Nedelio    male  19.0
# 879      0     3                             Laleff, Mr. Kristo    male   NaN
# 880      1     1  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 881      1     2   Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0
# 882      0     3                             Markun, Mr. Johann    male  33.0
# 883      0     3                   Dahlberg, Miss. Gerda Ulrika  female  22.0
# 884      0     2                  Banfield, Mr. Frederick James    male  28.0
# 885      0     3                         Sutehall, Mr. Henry Jr    male  25.0
# 886      0     3           Rice, Mrs. William (Margaret Norton)  female  39.0
# 887      0     2                          Montvila, Rev. Juozas    male  27.0
# ...

# %%
#处理空值
df.isnull().head()
# Out:
#        是否幸存   仓位等级     姓名     性别     年龄  兄弟姐妹个数  父母子女个数   床票信息     票价     客舱  \
# 乘客ID
# 1     False  False  False  False  False   False   False  False  False   True
# 2     False  False  False  False  False   False   False  False  False  False
# 3     False  False  False  False  False   False   False  False  False   True
# 4     False  False  False  False  False   False   False  False  False  False
# 5     False  False  False  False  False   False   False  False  False   True
#
#        登陆港口
# 乘客ID
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False

# %%
df.to_csv('train_chinese.csv',encoding="gb2312") # gb2312 或者 utf-8

# %% [markdown]
# ## PART 2 pandas 基础

# %%
#Series数据类型
sdata = {'Ohio':35000,'Texa':30000,'Oregon':16000,'Utah':5000}

# %%
example_1 = pd.Series(sdata)

# %%
example_1
# Out:
# Ohio      35000
# Texa      30000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
# DataFrame数据类型
data = {'stata':['Ohio','Ohio','Ohio','Nevada','Nevada','Nevada'],
       'year':[2000,2001,2002,2001,2002,2003],'pop':[1.5,1.7,3.6,2.4,2.9,3.2]}

example_2 = pd.DataFrame(data)

# %%
example_2
# Out:
#     stata  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
df = pd.read_csv('train.csv')

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Cabin'].head(5)
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# Name: Cabin, dtype: object

# %%
df.Cabin.head(5)
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# Name: Cabin, dtype: object

# %%
test_1 = pd.read_csv('test.csv')

# %%
test_1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(['PassengerId','Name','Age','Ticket'],axis=1).head(3)
# Out:
#    Survived  Pclass     Sex  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male      1      0   7.2500   NaN        S
# 1         1       1  female      1      0  71.2833   C85        C
# 2         1       3  female      0      0   7.9250   NaN        S

# %% [markdown]
# ### 筛选的逻辑

# %%
df[df["Age"]<10].head(3)
# Out:
#     PassengerId  Survived  Pclass                             Name     Sex  \
# 7             8         0       3   Palsson, Master. Gosta Leonard    male
# 10           11         1       3  Sandstrom, Miss. Marguerite Rut  female
# 16           17         0       3             Rice, Master. Eugene    male
#
#     Age  SibSp  Parch   Ticket    Fare Cabin Embarked
# 7   2.0      3      1   349909  21.075   NaN        S
# 10  4.0      1      1  PP 9549  16.700    G6        S
# 16  2.0      4      1   382652  29.125   NaN        Q

# %%
midage = df[(df["Age"]>10)&(df["Age"]<50)]

# %%
midage.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 8             9         1       3
# 9            10         1       2
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %%
midage.loc[[8]]
# Out:
#    PassengerId  Survived  Pclass  \
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch  Ticket     Fare Cabin Embarked
# 8      2  347742  11.1333   NaN        S

# %%
midage = midage.reset_index(drop=True)

# %%
midage.loc[[8]]
# Out:
#    PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 8           14         0       3  Andersson, Mr. Anders Johan  male  39.0
#
#    SibSp  Parch  Ticket    Fare Cabin Embarked
# 8      1      5  347082  31.275   NaN        S

# %%
midage.loc[[100,105,108],['Pclass','Name','Sex']]
# Out:
#      Pclass                               Name   Sex
# 100       2  Byles, Rev. Thomas Roussel Davids  male
# 105       3           Cribb, Mr. John Hatfield  male
# 108       3                    Calic, Mr. Jovo  male

# %%
midage.iloc[[100,105,108]]
# Out:
#      PassengerId  Survived  Pclass                               Name   Sex  \
# 100          150         0       2  Byles, Rev. Thomas Roussel Davids  male
# 105          161         0       3           Cribb, Mr. John Hatfield  male
# 108          164         0       3                    Calic, Mr. Jovo  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 100  42.0      0      0  244310  13.0000   NaN        S
# 105  44.0      0      1  371362  16.1000   NaN        S
# 108  17.0      0      0  315093   8.6625   NaN        S

# %%
midage.iloc[[100,105,108],[2,3,4]]
# Out:
#      Pclass                               Name   Sex
# 100       2  Byles, Rev. Thomas Roussel Davids  male
# 105       3           Cribb, Mr. John Hatfield  male
# 108       3                    Calic, Mr. Jovo  male

# %% [markdown]
# ## loc按index索引，iloc按行号索引

# %% [markdown]
# ## PART 3 探索性数据分析

# %%
df = pd.read_csv('train.csv',names=['乘客ID','是否幸存','仓位等级','姓名','性别','年龄','兄弟姐妹个数','父母子女个数','床票信息','票价','客舱','登陆港口'],index_col='乘客ID',header=0)

# %%
df.head()
# Out:
#       是否幸存  仓位等级                                                 姓名      性别  \
# 乘客ID
# 1        0     3                            Braund, Mr. Owen Harris    male
# 2        1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3        1     3                             Heikkinen, Miss. Laina  female
# 4        1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5        0     3                           Allen, Mr. William Henry    male
#
#         年龄  兄弟姐妹个数  父母子女个数              床票信息       票价    客舱 登陆港口
# 乘客ID
# 1     22.0       1       0         A/5 21171   7.2500   NaN    S
# 2     38.0       1       0          PC 17599  71.2833   C85    C
# 3     26.0       0       0  STON/O2. 3101282   7.9250   NaN    S
# 4     35.0       1       0            113803  53.1000  C123    S
# 5     35.0       0       0            373450   8.0500   NaN    S

# %%
# example
frame = pd.DataFrame(np.arange(8).reshape((2,4)),
                    index=['2','1'],
                    columns=['d','c','b','a'])

# %%
frame
# Out:
#    d  c  b  a
# 2  0  1  2  3
# 1  4  5  6  7

# %%
frame.sort_index()
# Out:
#    d  c  b  a
# 1  4  5  6  7
# 2  0  1  2  3

# %%
frame.sort_values(by='c',ascending=False)
# Out:
#    d  c  b  a
# 1  4  5  6  7
# 2  0  1  2  3

# %%
frame.sort_values(by='d',ascending=False)
# Out:
#    d  c  b  a
# 1  4  5  6  7
# 2  0  1  2  3

# %%
frame.sort_values(by='c',ascending=True)
# Out:
#    d  c  b  a
# 2  0  1  2  3
# 1  4  5  6  7
